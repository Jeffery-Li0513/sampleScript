# %%
from matminer.featurizers.composition import alloy
from matminer.featurizers.conversions import StrToComposition

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error, accuracy_score, r2_score

from figrecipes import PlotlyFig
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data.csv')

# Convert formula to composition
data = StrToComposition().featurize_dataframe(data, 'formula')
# 然后基于composition计算特征
data = alloy.WenAlloys().featurize_dataframe(data, 'composition')
# Out:
# StrToComposition:   0%|          | 0/2000 [00:00<?, ?it/s]
# WenAlloys:   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
# 去除数据中的'formula', 'C11', 'C12', 'C44', 'a', 'b', 'c', 'G', 'B', 'E', 'v', 'Zener', 'composition', 'Weight Fraction', 'Atomic Fraction'
data.drop(['formula', 'C11', 'C12', 'C44', 'a', 'b', 'c', 'G', 'B', 'E', 'v', 'Zener', 'composition', 'Weight Fraction', 'Atomic Fraction'], axis=1, inplace=True)
data.drop(['Interant electrons', 'Interant s electrons', 'Interant p electrons', 'Interant d electrons', 'Interant f electrons'], axis=1, inplace=True)

data.dropna(axis=1, how='any', inplace=True)

# 选择前1500条数据作为训练集和验证集；后500条数据作为验证集。
data_fit = data.iloc[:1500]
data_test = data.iloc[1500:]

# %%
data_fit_X = data_fit.drop('Pugh', axis=1)
data_fit_y = data_fit['Pugh']
data_fit.dtypes
# Out:
# Nb                                    int64
# Mo                                    int64
# Ta                                    int64
# W                                     int64
# Pugh                                float64
# Yang delta                          float64
# Yang omega                          float64
# APE mean                            float64
# Radii local mismatch                float64
# Radii gamma                         float64
# Configuration entropy               float64
# Atomic weight mean                  float64
# Total weight                        float64
# Lambda entropy                      float64
# Electronegativity delta             float64
# Electronegativity local mismatch    float64
# VEC mean                            float64
# Mixing enthalpy                     float64
# Mean cohesive energy                float64
# Shear modulus mean                  float64
# Shear modulus delta                 float64
# Shear modulus local mismatch        float64
# Shear modulus strength model        float64
# dtype: object

# %%
data_fit.corr()
# Out:
#                                         Nb        Mo        Ta         W  \
# Nb                                1.000000 -0.318892 -0.333438 -0.374204
# Mo                               -0.318892  1.000000 -0.340382 -0.343044
# Ta                               -0.333438 -0.340382  1.000000 -0.289237
# W                                -0.374204 -0.343044 -0.289237  1.000000
# Pugh                              0.867078 -0.414675  0.158796 -0.619616
# Yang delta                       -0.465959 -0.586266  0.228781  0.834666
# Yang omega                       -0.564729  0.505880  0.380938 -0.298920
# APE mean                         -0.250950  0.575089 -0.187563 -0.136712
# Radii local mismatch             -0.516958 -0.495778  0.181220  0.842257
# Radii gamma                      -0.415125  0.218043 -0.643328  0.825190
# Configuration entropy            -0.021659 -0.001004  0.031433 -0.007410
# Atomic weight mean               -0.613276 -0.552769  0.558596  0.632086
# Total weight                     -0.613149 -0.552903  0.558602  0.632084
# Lambda entropy                   -0.470270 -0.552003  0.167768  0.863874
# Electronegativity delta           0.156575 -0.833155  0.177393  0.498977
# Electronegativity local mismatch -0.272526 -0.260401 -0.225631  0.753272
# VEC mean                         -0.604774  0.570214 -0.549167  0.576040
# Mixing enthalpy                   0.283227 -0.597640 -0.272210  0.570529
# Mean cohesive energy             -0.243080 -0.777568  0.215326  0.812110
# Shear modulus mean               -0.761098  0.273248 -0.290368  0.780007
# Shear modulus delta               0.916950 -0.647357 -0.108566 -0.180392
# Shear modulus local mismatch      0.433206 -0.554282 -0.514700  0.609591
# Shear modulus strength model     -0.828498  0.719668  0.206509 -0.075816
#
#                                       Pugh  Yang delta  Yang omega  APE mean  \
# Nb                                0.867078   -0.465959   -0.564729 -0.250950
# Mo                               -0.414675   -0.586266    0.505880  0.575089
# Ta                                0.158796    0.228781    0.380938 -0.187563
# W                                -0.619616    0.834666   -0.298920 -0.136712
# Pugh                              1.000000   -0.474657   -0.300321 -0.257702
# Yang delta                       -0.474657    1.000000   -0.226466 -0.411039
# Yang omega                       -0.300321   -0.226466    1.000000  0.506716
# APE mean                         -0.257702   -0.411039    0.506716  1.000000
# Radii local mismatch             -0.553879    0.990344   -0.200040 -0.391685
# Radii gamma                      -0.793358    0.446563   -0.126819  0.180557
# Configuration entropy             0.054822   -0.136478   -0.096847  0.325947
# Atomic weight mean               -0.426909    0.905832    0.065341 -0.257834
# Total weight                     -0.426784    0.905849    0.065237 -0.257917
# Lambda entropy                   -0.504574    0.989976   -0.227870 -0.380172
# Electronegativity delta           0.117998    0.743746   -0.674886 -0.737441
# Electronegativity local mismatch -0.521675    0.758013   -0.501250 -0.435591
# VEC mean                         -0.902756    0.219785    0.178806  0.380895
# Mixing enthalpy                   0.021734    0.587486   -0.840045 -0.633108
# Mean cohesive energy             -0.244735    0.940203   -0.327614 -0.399307
# Shear modulus mean               -0.965499    0.561353    0.159504  0.227707
# Shear modulus delta               0.850657   -0.116392   -0.670994 -0.505425
# Shear modulus local mismatch      0.077569    0.460448   -0.802131 -0.495735
# Shear modulus strength model     -0.678362   -0.091846    0.770792  0.559480
#
#                                   Radii local mismatch  Radii gamma  ...  \
# Nb                                           -0.516958    -0.415125  ...
# Mo                                           -0.495778     0.218043  ...
# Ta                                            0.181220    -0.643328  ...
# W                                             0.842257     0.825190  ...
# Pugh                                         -0.553879    -0.793358  ...
# Yang delta                                    0.990344     0.446563  ...
# Yang omega                                   -0.200040    -0.126819  ...
# APE mean                                     -0.391685     0.180557  ...
# Radii local mismatch                          1.000000     0.505317  ...
# Radii gamma                                   0.505317     1.000000  ...
# Configuration entropy                        -0.218766    -0.012938  ...
# Atomic weight mean                            0.876023     0.203213  ...
# Total weight                                  0.876025     0.203149  ...
# Lambda entropy                                0.977467     0.502678  ...
# Electronegativity delta                       0.715949     0.036430  ...
# Electronegativity local mismatch              0.817591     0.620969  ...
# VEC mean                                      0.305170     0.911429  ...
# Mixing enthalpy                               0.595456     0.309572  ...
# Mean cohesive energy                          0.894015     0.341940  ...
# Shear modulus mean                            0.624634     0.905323  ...
# Shear modulus delta                          -0.185363    -0.437710  ...
# Shear modulus local mismatch                  0.457005     0.419703  ...
# Shear modulus strength model                 -0.032381     0.213957  ...
#
#                                   Lambda entropy  Electronegativity delta  \
# Nb                                     -0.470270                 0.156575
# Mo                                     -0.552003                -0.833155
# Ta                                      0.167768                 0.177393
# W                                       0.863874                 0.498977
# Pugh                                   -0.504574                 0.117998
# Yang delta                              0.989976                 0.743746
# Yang omega                             -0.227870                -0.674886
# APE mean                               -0.380172                -0.737441
# Radii local mismatch                    0.977467                 0.715949
# Radii gamma                             0.502678                 0.036430
# Configuration entropy                  -0.081046                -0.277413
# Atomic weight mean                      0.882325                 0.560767
# Total weight                            0.882338                 0.560868
# Lambda entropy                          1.000000                 0.702620
# Electronegativity delta                 0.702620                 1.000000
# Electronegativity local mismatch        0.744930                 0.705147
# VEC mean                                0.275147                -0.288646
# Mixing enthalpy                         0.565670                 0.887520
# Mean cohesive energy                    0.930062                 0.777252
# Shear modulus mean                      0.602326                -0.018941
# Shear modulus delta                    -0.135489                 0.506276
# Shear modulus local mismatch            0.467055                 0.731371
# Shear modulus strength model           -0.072840                -0.650980
#
#                                   Electronegativity local mismatch  VEC mean  \
# Nb                                                       -0.272526 -0.604774
# Mo                                                       -0.260401  0.570214
# Ta                                                       -0.225631 -0.549167
# W                                                         0.753272  0.576040
# Pugh                                                     -0.521675 -0.902756
# Yang delta                                                0.758013  0.219785
# Yang omega                                               -0.501250  0.178806
# APE mean                                                 -0.435591  0.380895
# Radii local mismatch                                      0.817591  0.305170
# Radii gamma                                               0.620969  0.911429
# Configuration entropy                                    -0.393613 -0.007354
# Atomic weight mean                                        0.469688  0.071765
# Total weight                                              0.469688  0.071648
# Lambda entropy                                            0.744930  0.275147
# Electronegativity delta                                   0.705147 -0.288646
# Electronegativity local mismatch                          1.000000  0.432177
# VEC mean                                                  0.432177  1.000000
# Mixing enthalpy                                           0.822903 -0.021118
# Mean cohesive energy                                      0.610338  0.033582
# Shear modulus mean                                        0.583765  0.919955
# Shear modulus delta                                      -0.056657 -0.721112
# Shear modulus local mismatch                              0.677516  0.050775
# Shear modulus strength model                             -0.171084  0.559969
#
#                                   Mixing enthalpy  Mean cohesive energy  \
# Nb                                       0.283227             -0.243080
# Mo                                      -0.597640             -0.777568
# Ta                                      -0.272210              0.215326
# W                                        0.570529              0.812110
# Pugh                                     0.021734             -0.244735
# Yang delta                               0.587486              0.940203
# Yang omega                              -0.840045             -0.327614
# APE mean                                -0.633108             -0.399307
# Radii local mismatch                     0.595456              0.894015
# Radii gamma                              0.309572              0.341940
# Configuration entropy                   -0.326715              0.003945
# Atomic weight mean                       0.260558              0.869274
# Total weight                             0.260646              0.869331
# Lambda entropy                           0.565670              0.930062
# Electronegativity delta                  0.887520              0.777252
# Electronegativity local mismatch         0.822903              0.610338
# VEC mean                                -0.021118              0.033582
# Mixing enthalpy                          1.000000              0.601743
# Mean cohesive energy                     0.601743              1.000000
# Shear modulus mean                       0.108405              0.386781
# Shear modulus delta                      0.510400              0.105957
# Shear modulus local mismatch             0.920585              0.542701
# Shear modulus strength model            -0.694219             -0.300568
#
#                                   Shear modulus mean  Shear modulus delta  \
# Nb                                         -0.761098             0.916950
# Mo                                          0.273248            -0.647357
# Ta                                         -0.290368            -0.108566
# W                                           0.780007            -0.180392
# Pugh                                       -0.965499             0.850657
# Yang delta                                  0.561353            -0.116392
# Yang omega                                  0.159504            -0.670994
# APE mean                                    0.227707            -0.505425
# Radii local mismatch                        0.624634            -0.185363
# Radii gamma                                 0.905323            -0.437710
# Configuration entropy                       0.000127            -0.100769
# Atomic weight mean                          0.455626            -0.267211
# Total weight                                0.455525            -0.267057
# Lambda entropy                              0.602326            -0.135489
# Electronegativity delta                    -0.018941             0.506276
# Electronegativity local mismatch            0.583765            -0.056657
# VEC mean                                    0.919955            -0.721112
# Mixing enthalpy                             0.108405             0.510400
# Mean cohesive energy                        0.386781             0.105957
# Shear modulus mean                          1.000000            -0.726355
# Shear modulus delta                        -0.726355             1.000000
# Shear modulus local mismatch                0.114099             0.585390
# Shear modulus strength model                0.521681            -0.958118
#
#                                   Shear modulus local mismatch  \
# Nb                                                    0.433206
# Mo                                                   -0.554282
# Ta                                                   -0.514700
# W                                                     0.609591
# Pugh                                                  0.077569
# Yang delta                                            0.460448
# Yang omega                                           -0.802131
# APE mean                                             -0.495735
# Radii local mismatch                                  0.457005
# Radii gamma                                           0.419703
# Configuration entropy                                -0.283180
# Atomic weight mean                                    0.096597
# Total weight                                          0.096694
# Lambda entropy                                        0.467055
# Electronegativity delta                               0.731371
# Electronegativity local mismatch                      0.677516
# VEC mean                                              0.050775
# Mixing enthalpy                                       0.920585
# Mean cohesive energy                                  0.542701
# Shear modulus mean                                    0.114099
# Shear modulus delta                                   0.585390
# Shear modulus local mismatch                          1.000000
# Shear modulus strength model                         -0.771276
#
#                                   Shear modulus strength model
# Nb                                                   -0.828498
# Mo                                                    0.719668
# Ta                                                    0.206509
# W                                                    -0.075816
# Pugh                                                 -0.678362
# Yang delta                                           -0.091846
# Yang omega                                            0.770792
# APE mean                                              0.559480
# Radii local mismatch                                 -0.032381
# Radii gamma                                           0.213957
# Configuration entropy                                 0.152923
# Atomic weight mean                                    0.124431
# Total weight                                          0.124279
# Lambda entropy                                       -0.072840
# Electronegativity delta                              -0.650980
# Electronegativity local mismatch                     -0.171084
# VEC mean                                              0.559969
# Mixing enthalpy                                      -0.694219
# Mean cohesive energy                                 -0.300568
# Shear modulus mean                                    0.521681
# Shear modulus delta                                  -0.958118
# Shear modulus local mismatch                         -0.771276
# Shear modulus strength model                          1.000000
#
# [23 rows x 23 columns]

# %% [markdown]
# 筛选出与因变量之间的相关性

# %%
cor = data_fit.corr()
cor_target = abs(cor["Pugh"])
# 挑选出大于0.5的相关系数
relevant_features = cor_target[cor_target>0.5]
relevant_features
# Out:
# Nb                                  0.867078
# W                                   0.619616
# Pugh                                1.000000
# Radii local mismatch                0.553879
# Radii gamma                         0.793358
# Lambda entropy                      0.504574
# Electronegativity local mismatch    0.521675
# VEC mean                            0.902756
# Shear modulus mean                  0.965499
# Shear modulus delta                 0.850657
# Shear modulus strength model        0.678362
# Name: Pugh, dtype: float64

# %% [markdown]
# 筛选出3个相关性比较大的自变量来，然后我们来看一下自变量之间的相关性如何，要是自变量之间的相关性非常强的话，我们也只需要保留其中的一个就行

# %%
print(data_fit[['Shear modulus mean', 'VEC mean']].corr())
print("=" * 50)
print(data_fit[['Shear modulus mean', 'Nb']].corr())
print("=" * 50)
print(data_fit[['VEC mean', 'Nb']].corr())
print("=" * 50)
# Out:
#                     Shear modulus mean  VEC mean
# Shear modulus mean            1.000000  0.919955
# VEC mean                      0.919955  1.000000
# ==================================================
#                     Shear modulus mean        Nb
# Shear modulus mean            1.000000 -0.761098
# Nb                           -0.761098  1.000000
# ==================================================
#           VEC mean        Nb
# VEC mean  1.000000 -0.604774
# Nb       -0.604774  1.000000
# ==================================================

# %% [markdown]
# 确定多少个变量能使模型的性能达到最优

# %%
from sklearn.feature_selection import RFE

features_num_list = np.arange(1, 22)            # 特征数目
high_score = 0                                  # 
num_feature = 0                                 # 最优特征数目
score_list = []                                 # 交叉验证得分
for n in range(len(features_num_list)):
    model = RandomForestRegressor()
    X_train, X_test, y_train, y_test = train_test_split(data_fit_X,data_fit_y, test_size = 0.3, random_state = 0)
    rfe_model = RFE(model, n_features_to_select=features_num_list[n])
    X_train_rfe = rfe_model.fit_transform(X_train, y_train)
    X_test_rfe = rfe_model.transform(X_test)
    model.fit(X_train_rfe, y_train)
    score = model.score(X_test_rfe, y_test)
    score_list.append(score)
    if(score > high_score):
        high_score = score
        num_feature = features_num_list[n]
print("Optimum number of features: %d" % num_feature)
print("Score with %d features: %f" % (num_feature, high_score))
# Out:
# Optimum number of features: 4
# Score with 4 features: 0.998705

# %% [markdown]
# 从上面可以看出4个变量对于整个模型来说是最优的，下面找出这四个特征

# %%
cols = list(data_fit_X.columns)
model = RandomForestRegressor()
#Initializing RFE model
rfe = RFE(model, n_features_to_select=4)
X_rfe = rfe.fit_transform(data_fit_X, data_fit_y) # Fit the data to model
model.fit(X_rfe, data_fit_y)
df = pd.Series(rfe.support_, index=cols)
selected_features_rfe = df[df==True].index
print(selected_features_rfe)
# Out:
# Index(['Nb', 'VEC mean', 'Shear modulus mean', 'Shear modulus delta'], dtype='object')
